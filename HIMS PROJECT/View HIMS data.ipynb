# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('hims.db')

# %%
df=pd.read_sql_query('select * from patients;')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=pd.read_sql_query('select * from patients;')
#
# TypeError: read_sql_query() missing 1 required positional argument: 'con'
